# %% [markdown]
# ## Dataset Preparation and Preprocessing

# %% [markdown]
# #### Import Packages

# %%
import pandas as pd
import numpy as np

# Importing rdkit to extract chemical features of the drugs
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# #### Define smiles, oneil_dataset dataframes

# %%
smiles = pd.read_csv('Datasets/smile.csv')
smiles.head()
# Out:
#         drug_name                                             smiles
# 0  5-Fluorouracil                            O=c1[nH]cc(F)c(=O)[nH]1
# 1       Veliparib                CC1(CCCN1)C2=NC3=C(C=CC=C3N2)C(=O)N
# 2         MK-1775  CC(C)(C1=NC(=CC=C1)N2C3=NC(=NC=C3C(=O)N2CC=C)N...
# 3     915019-65-7  CC(C)(C#N)C1=CC=C(C=C1)N2C3=C4C=C(C=CC4=NC=C3N...
# 4      Bortezomib  B(C(CC(C)C)NC(=O)C(CC1=CC=CC=C1)NC(=O)C2=NC=CN...

# %%
# Defining main dataframe on oneildataset.csv

oneil_ds = pd.read_csv('Datasets/oneildataset.csv')
oneil_ds.head()
# Out:
#    block_id        drug_row   drug_col cell_line_name study_name tissue_name  \
# 0     16145  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
# 1     16146  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
# 2     16147  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
# 3     16148  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
# 4     16149  5-Fluorouracil    MK-1775        EFM192B      ONEIL      breast
#
#   conc_row_unit conc_col_unit  ic50_row  ic50_col  ...   S_mean    S_max  \
# 0            uM            uM      10.0      10.0  ...  20.4610  10.0815
# 1            uM            uM      10.0      10.0  ...  14.8460   4.4665
# 2            uM            uM      10.0      10.0  ...  23.3770  12.9975
# 3            uM            uM      10.0      10.0  ...  17.9165   7.5370
# 4            uM            uM      10.0       0.5  ...  26.5910  26.3835
#
#    synergy_zip  synergy_loewe  synergy_hsa  synergy_bliss  \
# 0    -3.608485     -10.705039    -2.050132      -0.719085
# 1    -9.420828     -12.552164    -3.897257      -2.566210
# 2     3.657530      -4.027289     4.627618       5.958665
# 3     0.521115      -9.395789    -0.740882       0.590165
# 4    -8.567179      -1.107976     2.664619      -5.781006
#
#    drug_row_clinical_phase  drug_col_clinical_phase  \
# 0                        4                        3
# 1                        4                        3
# 2                        4                        3
# 3                        4                        3
# 4                        4                        2
#
#                                 drug_row_target_name  \
# 0  Prelamin-A/C; Survival motor neuron protein; T...
# 1  Prelamin-A/C; Survival motor neuron protein; T...
# 2  Prelamin-A/C; Survival motor neuron protein; T...
# 3  Prelamin-A/C; Survival motor neuron protein; T...
# 4  Prelamin-A/C; Survival motor neuron protein; T...
#
#                                 drug_col_target_name
# 0  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...
# 1  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...
# 2  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...
# 3  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...
# 4  Serine/threonine-protein kinase TBK1; Protein ...
#
# [5 rows x 26 columns]

# %%
oneil_ds.columns
# Out:
# Index(['block_id', 'drug_row', 'drug_col', 'cell_line_name', 'study_name',
#        'tissue_name', 'conc_row_unit', 'conc_col_unit', 'ic50_row', 'ic50_col',
#        'ri_row', 'ri_col', 'css_row', 'css_col', 'css_ri', 'S_sum', 'S_mean',
#        'S_max', 'synergy_zip', 'synergy_loewe', 'synergy_hsa', 'synergy_bliss',
#        'drug_row_clinical_phase', 'drug_col_clinical_phase',
#        'drug_row_target_name', 'drug_col_target_name'],
#       dtype='object')

# %% [markdown]
# #### Dataset Preprocessing

# %%
# extract features from drugs. we used lipinski's rule of five descriptors 

# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

df_lipinski = lipinski(smiles.smiles) # storing features in a dataframe

df_lipinski.head(2)
# Out:
#         MW    LogP  NumHDonors  NumHAcceptors
# 0  130.078 -0.7977         2.0            2.0
# 1  244.298  1.2604         3.0            3.0

# %%
smiles_with_descriptors = pd.concat([smiles, df_lipinski], axis=1) # concatening individual drugs and its features

smiles_with_descriptors
# Out:
#                          drug_name  \
# 0                   5-Fluorouracil
# 1                        Veliparib
# 2                          MK-1775
# 3                      915019-65-7
# 4                       Bortezomib
# 5                    Carboplatinum
# 6                 cyclophosphamide
# 7                        Dasatinib
# 8                    dexamethasone
# 9                       Dinaciclib
# 10                     doxorubicin
# 11                       Erlotinib
# 12                       etoposide
# 13                    geldanamycin
# 14                     gemcitabine
# 15              L-778123 free base
# 16                       Lapatinib
# 17                       metformin
# 18                    methotrexate
# 19                     mitomycin C
# 20                         MK-2206
# 21                         MK-4541
# 22                       Niraparib
# 23                         MK-5108
# 24                     Deforolimus
# 25                          MRK003
# 26                   Eloxatin (TN)
# 27                      paclitaxel
# 28                     391210-10-9
# 29  7-Ethyl-10-hydroxycamptothecin
# 30                       Sorafenib
# 31                       Sunitinib
# 32                    temozolomide
# 33                       topotecan
# 34                     vinblastine
# 35                     vinorelbine
# 36                      Vorinostat
# 37                     891494-63-6
# 38                         MK-4541
#
#                                                smiles       MW     LogP  \
# 0                             O=c1[nH]cc(F)c(=O)[nH]1  130.078 -0.79770
# 1                 CC1(CCCN1)C2=NC3=C(C=CC=C3N2)C(=O)N  244.298  1.26040
# 2   CC(C)(C1=NC(=CC=C1)N2C3=NC(=NC=C3C(=O)N2CC=C)N...  500.607  2.88600
# 3   CC(C)(C#N)C1=CC=C(C=C1)N2C3=C4C=C(C=CC4=NC=C3N...  469.548  5.89378
# 4   B(C(CC(C)C)NC(=O)C(CC1=CC=CC=C1)NC(=O)C2=NC=CN...  384.245  0.36060
# 5                     C1CC(C1)(C(=O)O)C(=O)O.N.N.[Pt]  373.266  0.64740
# 6                           C1CNP(=O)(OC1)N(CCCl)CCCl  261.089  1.88400
# 7   CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(...  488.017  3.31354
# 8   CC1CC2C3CCC4=CC(=O)C=CC4(C3(C(CC2(C1(C(=O)CO)O...  392.467  1.89570
# 9   CCC1=C2N=C(C=C(N2N=C1)NCC3=C[N+](=CC=C3)[O-])N...  396.495  2.27850
# 10  CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C...  543.525  0.00130
# 11  COCCOC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC=CC(=C3)C#C...  393.443  3.40510
# 12  CC1OCC2C(O1)C(C(C(O2)OC3C4COC(=O)C4C(C5=CC6=C(...  588.562  1.33860
# 13  CC1CC(C(C(C=C(C(C(C=CC=C(C(=O)NC2=CC(=O)C(=C(C...  560.644  2.40840
# 14              C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)(F)F  263.200 -1.28860
# 15  C1CN(C(=O)CN1CC2=CN=CN2CC3=CC=C(C=C3)C#N)C4=CC...  405.889  3.30528
# 16  CS(=O)(=O)CCNCC1=CC=C(O1)C2=CC3=C(C=C2)N=CN=C3...  581.069  6.13910
# 17                                  CN(C)C(=N)N=C(N)N  129.167 -1.24383
# 18  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...  454.447  0.26840
# 19  CC1=C(C(=O)C2=C(C1=O)N3CC4C(C3(C2COC(=O)N)OC)N4)N  334.332 -1.65120
# 20  C1CC(C1)(C2=CC=C(C=C2)C3=C(C=C4C(=N3)C=CN5C4=N...  407.477  4.24270
# 21  CC12CCC3C(C1CCC2NC(=O)OCC(F)(F)F)CCC4C3(C=CC(=...  428.495  4.28290
# 22   C1CC(CNC1)C2=CC=C(C=C2)N3C=C4C=CC=C(C4=N3)C(=O)N  320.396  2.59140
# 23  C1CC(CCC1OC2=C(C(=CC=C2)Cl)F)(CC3=NC(=CC=C3)NC...  461.946  5.70930
# 24  CC1CCC2CC(C(=CC=CC=CC(CC(C(=O)C(C(C(=CC(C(=O)C...  990.222  7.74260
# 25  C1CC2CC3=C(CC1C24CN(S(=O)(=O)N4)CC(F)(F)F)C=CC...  551.597  4.55000
# 26         C1CCC(C(C1)N)N.C(=O)(C(=O)[O-])[O-].[Pt+2]  397.288 -3.30130
# 27  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...  853.918  3.73570
# 28  C1=CC(=C(C=C1I)F)NC2=C(C=CC(=C2F)F)C(=O)NOCC(CO)O  482.196  2.46670
# 29  CCC1=C2CN3C(=CC4=C(C3=O)COC(=O)C4(CC)O)C2=NC5=...  392.411  2.34760
# 30  CNC(=O)C1=NC=CC(=C1)OC2=CC=C(C=C2)NC(=O)NC3=CC...  464.831  5.54970
# 31  CCN(CC)CCNC(=O)C1=C(NC(=C1C)C=C2C3=C(C=CC(=C3)...  398.482  3.33494
# 32                      CN1C(=O)N2C=NC(=C2N=N1)C(=O)N  194.154 -2.07810
# 33  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=C(C=CC(=C5CN(C...  421.453  1.84680
# 34  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...  810.989  3.99090
# 35  CCC1=CC2CC(C3=C(CN(C2)C1)C4=CC=CC=C4N3)(C5=C(C...  778.947  4.75360
# 36                   C1=CC=C(C=C1)NC(=O)CCCCCCC(=O)NO  264.325  2.47110
# 37     CN1C=C(C=N1)C2=C3N=C(C(=C(N3N=C2)N)Br)C4CCCNC4  376.262  1.94150
# 38  CC12CCC3C(C1CCC2NC(=O)OCC(F)(F)F)CCC4C3(C=CC(=...  428.495  4.28290
#
#     NumHDonors  NumHAcceptors
# 0          2.0            2.0
# 1          3.0            3.0
# 2          2.0           10.0
# 3          0.0            6.0
# 4          4.0            6.0
# 5          4.0            4.0
# 6          1.0            2.0
# 7          3.0            9.0
# 8          3.0            5.0
# 9          2.0            7.0
# 10         6.0           12.0
# 11         1.0            7.0
# 12         3.0           13.0
# 13         3.0            9.0
# 14         3.0            7.0
# 15         0.0            5.0
# 16         2.0            8.0
# 17         3.0            1.0
# 18         5.0           10.0
# 19         3.0            8.0
# 20         2.0            5.0
# 21         1.0            3.0
# 22         2.0            4.0
# 23         2.0            6.0
# 24         2.0           14.0
# 25         1.0            3.0
# 26         2.0            6.0
# 27         4.0           14.0
# 28         4.0            5.0
# 29         2.0            7.0
# 30         3.0            4.0
# 31         3.0            3.0
# 32         1.0            7.0
# 33         2.0            8.0
# 34         3.0           12.0
# 35         2.0           11.0
# 36         3.0            3.0
# 37         2.0            7.0
# 38         1.0            3.0

# %%
smiles_with_descriptors.to_csv('smile_with_desc.csv',index=False) # saving the output in a csv file for later use

smile_with_desc = pd.read_csv('smile_with_desc.csv')

# %%
# finding all the possible two-drug combinations from the smiles_with_desc dataframe and storing it in an empty list

import itertools

drug_comb = []
for L in range(0, len(smile_with_desc.drug_name)+1):
    for subset in itertools.combinations(smile_with_desc.drug_name, 2): # 2 is used to restrict the code in forming only 2 combinaitons
        drug_comb.append(subset)

# %%
drug_comb[0:6]
# Out:
# [('5-Fluorouracil', 'Veliparib'),
#  ('5-Fluorouracil', 'MK-1775'),
#  ('5-Fluorouracil', '915019-65-7'),
#  ('5-Fluorouracil', 'Bortezomib'),
#  ('5-Fluorouracil', 'Carboplatinum'),
#  ('5-Fluorouracil', 'cyclophosphamide')]

# %% [markdown]
# ##### Creating a dataframe of the combined drugs

# %%
df_final = pd.DataFrame(columns = ['drug_row','drug_col'])

# %%
for i in drug_comb[:6]:
    print(i[0],i[1])
# Out:
# 5-Fluorouracil Veliparib
# 5-Fluorouracil MK-1775
# 5-Fluorouracil 915019-65-7
# 5-Fluorouracil Bortezomib
# 5-Fluorouracil Carboplatinum
# 5-Fluorouracil cyclophosphamide

# %%
for i in drug_comb:
    df_final= df_final.append({'drug_row':i[0],'drug_col':i[1]} ,ignore_index=True)

# %%
df_final.duplicated().value_counts()
# Out:
# True     28920
# False      720
# dtype: int64

# %%
df_final = df_final.drop_duplicates()

# %%
df_final
# Out:
#            drug_row       drug_col
# 0    5-Fluorouracil      Veliparib
# 1    5-Fluorouracil        MK-1775
# 2    5-Fluorouracil    915019-65-7
# 3    5-Fluorouracil     Bortezomib
# 4    5-Fluorouracil  Carboplatinum
# ..              ...            ...
# 736     vinorelbine    891494-63-6
# 737     vinorelbine        MK-4541
# 738      Vorinostat    891494-63-6
# 739      Vorinostat        MK-4541
# 740     891494-63-6        MK-4541
#
# [720 rows x 2 columns]

# %%
merge_df_final_drug1_with_smiles_features =  pd.merge(df_final , smile_with_desc ,how="left",left_on=['drug_row'],right_on=['drug_name'])

# %%
merge_df_final_drug1_with_smiles_features.head(2)
# Out:
#          drug_row   drug_col       drug_name                   smiles  \
# 0  5-Fluorouracil  Veliparib  5-Fluorouracil  O=c1[nH]cc(F)c(=O)[nH]1
# 1  5-Fluorouracil    MK-1775  5-Fluorouracil  O=c1[nH]cc(F)c(=O)[nH]1
#
#         MW    LogP  NumHDonors  NumHAcceptors
# 0  130.078 -0.7977         2.0            2.0
# 1  130.078 -0.7977         2.0            2.0

# %%
merge_df_final_drug2_with_smiles_features = merge_df_final_drug1_with_smiles_features.merge( smile_with_desc ,how="left",left_on=['drug_col'],right_on=['drug_name'],suffixes=('_row','_col'))

# %%
merge_df_final_drug2_with_smiles_features = merge_df_final_drug2_with_smiles_features.drop_duplicates()

# %%
merge_df_final_drug2_with_smiles_features.head(2)
# Out:
#          drug_row   drug_col   drug_name_row               smiles_row  \
# 0  5-Fluorouracil  Veliparib  5-Fluorouracil  O=c1[nH]cc(F)c(=O)[nH]1
# 1  5-Fluorouracil    MK-1775  5-Fluorouracil  O=c1[nH]cc(F)c(=O)[nH]1
#
#     MW_row  LogP_row  NumHDonors_row  NumHAcceptors_row drug_name_col  \
# 0  130.078   -0.7977             2.0                2.0     Veliparib
# 1  130.078   -0.7977             2.0                2.0       MK-1775
#
#                                           smiles_col   MW_col  LogP_col  \
# 0                CC1(CCCN1)C2=NC3=C(C=CC=C3N2)C(=O)N  244.298    1.2604
# 1  CC(C)(C1=NC(=CC=C1)N2C3=NC(=NC=C3C(=O)N2CC=C)N...  500.607    2.8860
#
#    NumHDonors_col  NumHAcceptors_col
# 0             3.0                3.0
# 1             2.0               10.0

# %%
merge_df_final_drug2_with_smiles_features.columns
# Out:
# Index(['drug_row', 'drug_col', 'drug_name_row', 'smiles_row', 'MW_row',
#        'LogP_row', 'NumHDonors_row', 'NumHAcceptors_row', 'drug_name_col',
#        'smiles_col', 'MW_col', 'LogP_col', 'NumHDonors_col',
#        'NumHAcceptors_col'],
#       dtype='object')

# %%
merge_df_final_drug2_with_smiles_features = merge_df_final_drug2_with_smiles_features.drop(labels=['drug_name_row', 'smiles_row','drug_name_col','smiles_col'], axis = 1)

# %%
merge_df_final_drug2_with_smiles_features.head(2)
# Out:
#          drug_row   drug_col   MW_row  LogP_row  NumHDonors_row  \
# 0  5-Fluorouracil  Veliparib  130.078   -0.7977             2.0
# 1  5-Fluorouracil    MK-1775  130.078   -0.7977             2.0
#
#    NumHAcceptors_row   MW_col  LogP_col  NumHDonors_col  NumHAcceptors_col
# 0                2.0  244.298    1.2604             3.0                3.0
# 1                2.0  500.607    2.8860             2.0               10.0

# %%
labls = ['drug_row','drug_col']

# %%
merged_df_with_oneil_ds = pd.merge(oneil_ds, merge_df_final_drug2_with_smiles_features,on = labls)

# %%
merged_df_with_oneil_ds.head(2)
# Out:
#    block_id        drug_row   drug_col cell_line_name study_name tissue_name  \
# 0     16145  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
# 1     16146  5-Fluorouracil  Veliparib        EFM192B      ONEIL      breast
#
#   conc_row_unit conc_col_unit  ic50_row  ic50_col  ...  \
# 0            uM            uM      10.0      10.0  ...
# 1            uM            uM      10.0      10.0  ...
#
#                                 drug_row_target_name  \
# 0  Prelamin-A/C; Survival motor neuron protein; T...
# 1  Prelamin-A/C; Survival motor neuron protein; T...
#
#                                 drug_col_target_name   MW_row  LogP_row  \
# 0  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...  130.078   -0.7977
# 1  Poly [ADP-ribose] polymerase-1; Poly [ADP-ribo...  130.078   -0.7977
#
#    NumHDonors_row  NumHAcceptors_row   MW_col  LogP_col  NumHDonors_col  \
# 0             2.0                2.0  244.298    1.2604             3.0
# 1             2.0                2.0  244.298    1.2604             3.0
#
#    NumHAcceptors_col
# 0                3.0
# 1                3.0
#
# [2 rows x 34 columns]

# %%
merged_df_with_oneil_ds.synergy_bliss
# Out:
# 0       -0.719085
# 1       -2.566210
# 2        5.958665
# 3        0.590165
# 4       -5.484395
#           ...
# 7255     0.833246
# 7256    -3.446151
# 7257   -10.614713
# 7258    -4.272463
# 7259   -11.578338
# Name: synergy_bliss, Length: 7260, dtype: float64

# %%
# Dropping unwanted columns from the dataset

columns_to_drop = ['tissue_name','study_name','conc_row_unit', 'conc_col_unit','drug_row_target_name', 'drug_col_target_name']

merged_df_with_oneil_ds = merged_df_with_oneil_ds.drop(labels=columns_to_drop, axis=1)

merged_df_with_oneil_ds.head(2)
# Out:
#    block_id        drug_row   drug_col cell_line_name  ic50_row  ic50_col  \
# 0     16145  5-Fluorouracil  Veliparib        EFM192B      10.0      10.0
# 1     16146  5-Fluorouracil  Veliparib        EFM192B      10.0      10.0
#
#    ri_row  ri_col  css_row  css_col  ...  drug_row_clinical_phase  \
# 0  19.098  -1.661   23.201   35.158  ...                        4
# 1  19.098  -1.661   16.258   30.871  ...                        4
#
#    drug_col_clinical_phase   MW_row  LogP_row  NumHDonors_row  \
# 0                        3  130.078   -0.7977             2.0
# 1                        3  130.078   -0.7977             2.0
#
#    NumHAcceptors_row   MW_col  LogP_col  NumHDonors_col  NumHAcceptors_col
# 0                2.0  244.298    1.2604             3.0                3.0
# 1                2.0  244.298    1.2604             3.0                3.0
#
# [2 rows x 28 columns]

# %%
# encoding cell_line_name

merged_df_with_oneil_ds['cell_line_name'].unique().tolist()
# Out:
# ['EFM192B', 'KPL1', 'MDAMB436', 'OCUBM', 'T-47D', 'ZR751']

# %%
encode = {'EFM192B':1, 'KPL1':2, 'MDAMB436':3, 'OCUBM':4, 'T-47D':5, 'ZR751':6}

# %%
merged_df_with_oneil_ds = merged_df_with_oneil_ds.replace({'cell_line_name':encode})

# %%
merged_df_with_oneil_ds['cell_line_name'].unique().tolist()
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
merged_df_with_oneil_ds.head()
# Out:
#    block_id        drug_row   drug_col  cell_line_name   ic50_row   ic50_col  \
# 0     16145  5-Fluorouracil  Veliparib               1  10.000000  10.000000
# 1     16146  5-Fluorouracil  Veliparib               1  10.000000  10.000000
# 2     16147  5-Fluorouracil  Veliparib               1  10.000000  10.000000
# 3     16148  5-Fluorouracil  Veliparib               1  10.000000  10.000000
# 4     27701  5-Fluorouracil  Veliparib               2   8.055629   3.896132
#
#    ri_row  ri_col  css_row  css_col  ...  drug_row_clinical_phase  \
# 0  19.098  -1.661   23.201   35.158  ...                        4
# 1  19.098  -1.661   16.258   30.871  ...                        4
# 2  19.098  -1.661   23.611   40.580  ...                        4
# 3  19.098  -1.661   19.803   33.467  ...                        4
# 4  22.529   5.580   29.098   41.526  ...                        4
#
#    drug_col_clinical_phase   MW_row  LogP_row  NumHDonors_row  \
# 0                        3  130.078   -0.7977             2.0
# 1                        3  130.078   -0.7977             2.0
# 2                        3  130.078   -0.7977             2.0
# 3                        3  130.078   -0.7977             2.0
# 4                        3  130.078   -0.7977             2.0
#
#    NumHAcceptors_row   MW_col  LogP_col  NumHDonors_col  NumHAcceptors_col
# 0                2.0  244.298    1.2604             3.0                3.0
# 1                2.0  244.298    1.2604             3.0                3.0
# 2                2.0  244.298    1.2604             3.0                3.0
# 3                2.0  244.298    1.2604             3.0                3.0
# 4                2.0  244.298    1.2604             3.0                3.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### Forming a dataset with only the Synergy_bliss values

# %%
bliss_labels = ['synergy_hsa', 'synergy_zip','synergy_loewe',]
main_syn_bliss = merged_df_with_oneil_ds.drop(labels=bliss_labels, axis =1)

# %%
main_syn_bliss.to_csv('Datasets/main_syn_bliss.csv', index=False)

# %% [markdown]
# # Next step is to apply machine learning models to the dataset
